# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# 1.Prepare Dataset
X = np.array([
    [1, 60],
    [2, 65],
    [3, 70],
    [4, 75],
    [5, 85]
])

y = np.array([0, 0, 1, 1, 1]) # 0 = Fail, 1 = Pass

# %%
# 2. Create Pipeline
model = Pipeline([
    ("scaler", StandardScaler()),
    ("log_reg", LogisticRegression())
])

# %%
# 3. Train Model
model.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('log_reg', LogisticRegression())])

# %%
# 4. Take User Input
study_hours = float(input("Enter Study Hours: "))
attendance = float(input("Enter Attendance: "))

user_data = np.array([[study_hours, attendance]])
# Out:
# Enter Study Hours:  6
# Enter Attendance:  86

# %%
# 5. Prediction
probability = model.predict_proba(user_data)[0][1]
prediction = model.predict(user_data)[0]
print("\nProbability of Passing:", round(probability, 3))

if pediction == 1:
    print("Result: Pass")
else:
    print("Result: Fail")
# Out:
# Probability of Passing: 0.97
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 prediction = model.predict(user_data)[0]
#       4 print("\nProbability of Passing:", round(probability, 3))
# ----> 6 if pediction == 1:
#       7     print("Result: Pass")
#       8 else:
#
# NameError: name 'pediction' is not defined
